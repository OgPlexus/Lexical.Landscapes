# %% [markdown]
# # Output Cell Toggle Button

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # Cw Figures - Main Text

# %%
import re
import gc
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

import pandas as pd
import pylab as p
import os
import csv
import numpy as np

from scipy.integrate import odeint

files = [\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Cw Data/Cw CARS CARE CAME COME SOME.csv',\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Cw Data/Cw CARS CARE CAME SAME SOME.csv',\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Cw Data/Cw POEM POET POST LOST LAST.csv',\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Cw Data/Cw POEM POET POST PAST LAST.csv',\
        ]

path1 = pd.read_csv(files[0],sep =',', lineterminator ='\n',header =None)
path2 = pd.read_csv(files[1],sep =',', lineterminator ='\n',header =None)
path6 = pd.read_csv(files[2],sep =',', lineterminator ='\n',header =None)
path7 = pd.read_csv(files[3],sep =',', lineterminator ='\n',header =None)

# %%
path1 = path1.transpose()
path1.columns = ['Year', 'Up/Down', 'Cw Value']
path1['Year'] = path1['Year'].astype(int)
columnsTitles=["Year","Cw Value","Up/Down"]
path1=path1.reindex(columns=columnsTitles)

for i in range(len(path1)):
    if path1.loc[i,'Up/Down'] == 1:
        path1.loc[i,'Up/Down'] = path1.loc[i,'Cw Value']
    else:
        path1.loc[i,'Up/Down'] = path1.loc[i,'Up/Down']
        
for i in range(len(path1)):
    if path1.loc[i,'Up/Down'] == 0:
        path1.loc[i,'Up/Down'] = None
    else:
        path1.loc[i,'Up/Down'] = path1.loc[i,'Up/Down']

#-------------------------------------------------------------------------------
        
path2 = path2.transpose()
path2.columns = ['Year', 'Up/Down', 'Cw Value']
path2['Year'] = path2['Year'].astype(int)
columnsTitles=["Year","Cw Value","Up/Down"]
path2=path2.reindex(columns=columnsTitles)

for i in range(len(path2)):
    if path2.loc[i,'Up/Down'] == 1:
        path2.loc[i,'Up/Down'] = path2.loc[i,'Cw Value']
    else:
        path2.loc[i,'Up/Down'] = path2.loc[i,'Up/Down']
        
for i in range(len(path2)):
    if path2.loc[i,'Up/Down'] == 0:
        path2.loc[i,'Up/Down'] = None
    else:
        path2.loc[i,'Up/Down'] = path2.loc[i,'Up/Down']
        
#-------------------------------------------------------------------------------
        
path6 = path6.transpose()
path6.columns = ['Year', 'Up/Down', 'Cw Value']
path6['Year'] = path6['Year'].astype(int)
columnsTitles=["Year","Cw Value","Up/Down"]
path6=path6.reindex(columns=columnsTitles)

for i in range(len(path6)):
    if path6.loc[i,'Up/Down'] == 1:
        path6.loc[i,'Up/Down'] = path6.loc[i,'Cw Value']
    else:
        path6.loc[i,'Up/Down'] = path6.loc[i,'Up/Down']
        
for i in range(len(path6)):
    if path6.loc[i,'Up/Down'] == 0:
        path6.loc[i,'Up/Down'] = None
    else:
        path6.loc[i,'Up/Down'] = path6.loc[i,'Up/Down']
        
#-------------------------------------------------------------------------------
        
path7 = path7.transpose()
path7.columns = ['Year', 'Up/Down', 'Cw Value']
path7['Year'] = path7['Year'].astype(int)
columnsTitles=["Year","Cw Value","Up/Down"]
path7=path7.reindex(columns=columnsTitles)

for i in range(len(path7)):
    if path7.loc[i,'Up/Down'] == 1:
        path7.loc[i,'Up/Down'] = path7.loc[i,'Cw Value']
    else:
        path7.loc[i,'Up/Down'] = path7.loc[i,'Up/Down']
        
for i in range(len(path7)):
    if path7.loc[i,'Up/Down'] == 0:
        path7.loc[i,'Up/Down'] = None
    else:
        path7.loc[i,'Up/Down'] = path7.loc[i,'Up/Down']

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 10

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Year", y="Cw Value", data=path1, alpha=0.4)
sns.scatterplot(x="Year", y="Up/Down", data=path1, color='r', s=140)

b.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"CARS$\rightarrow$SOME within-path competition ($C_W$)",fontsize=45, pad=10)
b.set_xlabel("Context (years)",fontsize=35)
b.set_ylabel("Within-path competition ($C_W$)",fontsize=35)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
b.text(0.46,0.23,r'CARS$\rightarrow$CARE$\rightarrow$CAME$\rightarrow$COME$\rightarrow$SOME',\
       transform=b.transAxes, fontsize=25)
for tick in b.get_xticklabels():
    tick.set_rotation(30)

# plt.tight_layout()
# plt.savefig('F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
# Epistasis & Lexical Landscapes/Fancy Plots/Done/Main Text Figures/CwCS', dpi=100)

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 10

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Year", y="Cw Value", data=path2, alpha=0.4)
sns.scatterplot(x="Year", y="Up/Down", data=path2, color='r', s=140)

b.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title("CARS to SOME",fontsize=35, pad=10)
b.set_xlabel("Context (Years)",fontsize=30)
b.set_ylabel("$C_W$",fontsize=30)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
b.text(0.485,0.68,r'CARS$\rightarrow$CARE$\rightarrow$CAME$\rightarrow$SAME$\rightarrow$SOME',\
       transform=b.transAxes, fontsize=25)
for tick in b.get_xticklabels():
    tick.set_rotation(30)

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 10

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Year", y="Cw Value", data=path6, alpha=0.4)
sns.scatterplot(x="Year", y="Up/Down", data=path6, color='r', s=140)

b.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"POEM$\rightarrow$LAST within-path competition ($C_W$)",fontsize=45, pad=10)
b.set_xlabel("Context (years)",fontsize=35)
b.set_ylabel("Within-path competition ($C_W$)",fontsize=35)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
b.text(0.08,0.71,r'POEM$\rightarrow$POET$\rightarrow$POST$\rightarrow$LOST$\rightarrow$LAST',\
       transform=b.transAxes, fontsize=25)
for tick in b.get_xticklabels():
    tick.set_rotation(30)

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 10

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Year", y="Cw Value", data=path7, alpha=0.4)
sns.scatterplot(x="Year", y="Up/Down", data=path7, color='r', s=140)

b.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title("POEM to LAST",fontsize=35, pad=10)
b.set_xlabel("Context (Years)",fontsize=30)
b.set_ylabel("$C_W$",fontsize=30)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
b.text(0.10,0.72,r'POEM$\rightarrow$POET$\rightarrow$POST$\rightarrow$LOST$\rightarrow$LAST',\
       transform=b.transAxes, fontsize=25)
for tick in b.get_xticklabels():
    tick.set_rotation(30)

# %% [markdown]
# # Epi Figures - Main Text

# %%
import re
import gc
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib as mpl
import seaborn as sns

import pandas as pd
import pylab as p
import os
import csv
import numpy as np

from scipy.integrate import odeint

files = [\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Epi Data/Epi CARS to SOME Go.csv',\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Epi Data/Epi POEM to LAST Go.csv',\
        ]

EpiCS = pd.read_csv(files[0],sep =',', lineterminator ='\n')
EpiPL = pd.read_csv(files[1],sep =',', lineterminator ='\n')

EpiCS1 = EpiCS.dropna(axis=1)
EpiCS2 = EpiCS1.iloc[:, :-1]
EpiCS3 = EpiCS2.rename(columns={'Unnamed: 0':'Context (Years)'})

EpiPL3 = EpiPL.rename(columns={'Unnamed: 0':'Context (Years)'})

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 10

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Context (Years)", y="0th Order", data=EpiCS3, alpha=0.5, label='0th Order')
b = sns.lineplot(x="Context (Years)", y="1st Order", data=EpiCS3, alpha=0.5, label='1st Order')
b = sns.lineplot(x="Context (Years)", y="2nd Order", data=EpiCS3, alpha=0.5, label='2nd Order')
b = sns.lineplot(x="Context (Years)", y="3rd Order", data=EpiCS3, alpha=0.5, label='3rd Order')
b = sns.lineplot(x="Context (Years)", y="4th Order", data=EpiCS3, alpha=0.5, label='4th Order')

b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"CARS$\rightarrow$SOME epistasis (absolute mean)",fontsize=52, pad=10)
b.set_xlabel("Context (years)",fontsize=35)
b.set_ylabel("Epistasis (mean absolute value)",fontsize=30)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.yaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
# b.legend(loc='best', prop={'size': 25})
for tick in b.get_xticklabels():
    tick.set_rotation(30)
    
b.lines[0].set_markevery(2)
b.lines[0].set_marker(('s'))
b.lines[0].set_markersize(12)

b.lines[1].set_markevery(2)
b.lines[1].set_marker(('o'))
b.lines[1].set_markersize(12)

b.lines[2].set_markevery(2)
b.lines[2].set_marker(('D'))
b.lines[2].set_markersize(12)

b.lines[3].set_markevery(2)
b.lines[3].set_marker(('^'))
b.lines[3].set_markersize(12)

b.lines[4].set_markevery(2)
b.lines[4].set_marker(('X'))
b.lines[4].set_markersize(12)

b.legend(prop={'size': 20})

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 10

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Context (Years)", y="0th Order", data=EpiPL3, alpha=0.5, label='0th Order')
b = sns.lineplot(x="Context (Years)", y="1st Order", data=EpiPL3, alpha=0.5, label='1st Order')
b = sns.lineplot(x="Context (Years)", y="2nd Order", data=EpiPL3, alpha=0.5, label='2nd Order')
b = sns.lineplot(x="Context (Years)", y="3rd Order", data=EpiPL3, alpha=0.5, label='3rd Order')
b = sns.lineplot(x="Context (Years)", y="4th Order", data=EpiPL3, alpha=0.5, label='4th Order')

b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"POEM$\rightarrow$LAST epistasis (absolute mean)",fontsize=52, pad=10)
b.set_xlabel("Context (years)",fontsize=35)
b.set_ylabel("Epistasis (mean absolute value)",fontsize=30)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.yaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
for tick in b.get_xticklabels():
    tick.set_rotation(30)
    
b.lines[0].set_markevery(2)
b.lines[0].set_marker(('s'))
b.lines[0].set_markersize(12)

b.lines[1].set_markevery(2)
b.lines[1].set_marker(('o'))
b.lines[1].set_markersize(12)

b.lines[2].set_markevery(2)
b.lines[2].set_marker(('D'))
b.lines[2].set_markersize(12)

b.lines[3].set_markevery(2)
b.lines[3].set_marker(('^'))
b.lines[3].set_markersize(12)

b.lines[4].set_markevery(2)
b.lines[4].set_marker(('X'))
b.lines[4].set_markersize(12)

b.legend(prop={'size': 20})

# %% [markdown]
# # Simulation Figures - Main Text

# %%
import re
import gc
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib as mpl
import seaborn as sns

import pandas as pd
import pylab as p
import os
import csv
import numpy as np

from scipy.integrate import odeint

files = [\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Simulations/cars some1sim1950 clean.csv',\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Simulations/cars some1sim2000 clean.csv',\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Simulations/poem last14sim1950 clean.csv',\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Simulations/poem last14sim2000 clean.csv',\
        ]

SimCS50 = pd.read_csv(files[0],sep =',', lineterminator ='\n')
SimCS00 = pd.read_csv(files[1],sep =',', lineterminator ='\n')
SimPL50 = pd.read_csv(files[2],sep =',', lineterminator ='\n')
SimPL00 = pd.read_csv(files[3],sep =',', lineterminator ='\n')

SimCS502 = SimCS50[(SimCS50['Generations'] >= 45) & (SimCS50['Generations'] <= 105)]
SimCS002 = SimCS00[(SimCS00['Generations'] >= 40) & (SimCS00['Generations'] <= 80)]
SimPL502 = SimPL50[(SimPL50['Generations'] >= 35) & (SimPL50['Generations'] <= 50)]
SimPL002 = SimPL00[(SimCS50['Generations'] >= 30) & (SimPL00['Generations'] <= 55)]
# Out:
# C:\Users\Victor\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 7

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Generations", y="0000", data=SimCS502, alpha=0.5, label='CARS')
b = sns.lineplot(x="Generations", y="0001", data=SimCS502, alpha=0.5, label='CARE')
b = sns.lineplot(x="Generations", y="0011", data=SimCS502, alpha=0.5, label='CAME')
b = sns.lineplot(x="Generations", y="1011", data=SimCS502, alpha=0.5, label='SAME')
b = sns.lineplot(x="Generations", y="1111", data=SimCS502, alpha=0.5, label='SOME')

b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"CARS$\rightarrow$SOME 1950 simulation",fontsize=55, pad=10)
b.set_xlabel("Generations",fontsize=35)
b.set_ylabel("Relative values normalized",fontsize=35)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.yaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
for tick in b.get_xticklabels():
    tick.set_rotation(30)
    
b.lines[0].set_markevery(2)
b.lines[0].set_marker(('s'))
b.lines[0].set_markersize(12)

b.lines[1].set_markevery(2)
b.lines[1].set_marker(('o'))
b.lines[1].set_markersize(12)

b.lines[2].set_markevery(2)
b.lines[2].set_marker(('D'))
b.lines[2].set_markersize(12)

b.lines[3].set_markevery(2)
b.lines[3].set_marker(('^'))
b.lines[3].set_markersize(12)

b.lines[4].set_markevery(2)
b.lines[4].set_marker(('X'))
b.lines[4].set_markersize(12)

b.legend(prop={'size': 25})

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 7

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Generations", y="0000", data=SimCS002, alpha=0.5, label='CARS')
b = sns.lineplot(x="Generations", y="0001", data=SimCS002, alpha=0.5, label='CARE')
b = sns.lineplot(x="Generations", y="0011", data=SimCS002, alpha=0.5, label='CAME')
b = sns.lineplot(x="Generations", y="1011", data=SimCS002, alpha=0.5, label='SAME')
b = sns.lineplot(x="Generations", y="1111", data=SimCS002, alpha=0.5, label='SOME')

b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"CARS$\rightarrow$SOME 2000 simulation",fontsize=55, pad=10)
b.set_xlabel("Generations",fontsize=35)
b.set_ylabel("Relative values normalized",fontsize=35)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.yaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
for tick in b.get_xticklabels():
    tick.set_rotation(30)
    
b.lines[0].set_markevery(1)
b.lines[0].set_marker(('s'))
b.lines[0].set_markersize(12)

b.lines[1].set_markevery(1)
b.lines[1].set_marker(('o'))
b.lines[1].set_markersize(12)

b.lines[2].set_markevery(1)
b.lines[2].set_marker(('D'))
b.lines[2].set_markersize(12)

b.lines[3].set_markevery(1)
b.lines[3].set_marker(('^'))
b.lines[3].set_markersize(12)

b.lines[4].set_markevery(1)
b.lines[4].set_marker(('X'))
b.lines[4].set_markersize(12)

b.legend(prop={'size': 25})

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 7

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Generations", y="0000", data=SimPL502, alpha=0.5, label='POEM')
b = sns.lineplot(x="Generations", y="0001", data=SimPL502, alpha=0.5, label='POET')
b = sns.lineplot(x="Generations", y="0011", data=SimPL502, alpha=0.5, label='POST')
b = sns.lineplot(x="Generations", y="0111", data=SimPL502, alpha=0.5, label='PAST')
b = sns.lineplot(x="Generations", y="1111", data=SimPL502, alpha=0.5, label='LAST')

b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"POEM$\rightarrow$LAST 1950 simulation",fontsize=55, pad=10)
b.set_xlabel("Generations",fontsize=35)
b.set_ylabel("Relative values normalized",fontsize=35)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.yaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
for tick in b.get_xticklabels():
    tick.set_rotation(30)
    
    
b.lines[0].set_markevery(1)
b.lines[0].set_marker(('s'))
b.lines[0].set_markersize(12)

b.lines[1].set_markevery(1)
b.lines[1].set_marker(('o'))
b.lines[1].set_markersize(12)

b.lines[2].set_markevery(1)
b.lines[2].set_marker(('D'))
b.lines[2].set_markersize(12)

b.lines[3].set_markevery(1)
b.lines[3].set_marker(('^'))
b.lines[3].set_markersize(12)

b.lines[4].set_markevery(1)
b.lines[4].set_marker(('X'))
b.lines[4].set_markersize(12)

b.legend(prop={'size': 25})

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 7

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Generations", y="0000", data=SimPL002, alpha=0.5, label='POEM')
b = sns.lineplot(x="Generations", y="0011", data=SimPL002, alpha=0.5, label='POST')
b = sns.lineplot(x="Generations", y="0111", data=SimPL002, alpha=0.5, label='PAST')
b = sns.lineplot(x="Generations", y="1111", data=SimPL002, alpha=0.5, label='LAST')

b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"POEM$\rightarrow$LAST 2000 simulation",fontsize=55, pad=10)
b.set_xlabel("Generations",fontsize=35)
b.set_ylabel("Relative values normalized",fontsize=35)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.yaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
for tick in b.get_xticklabels():
    tick.set_rotation(30)
    
b.lines[1].set_markevery(1)
b.lines[1].set_marker(('o'))
b.lines[1].set_markersize(12)

b.lines[2].set_markevery(1)
b.lines[2].set_marker(('D'))
b.lines[2].set_markersize(12)

b.lines[3].set_markevery(1)
b.lines[3].set_marker(('^'))
b.lines[3].set_markersize(12)

b.lines[0].set_markevery(1)
b.lines[0].set_marker(('X'))
b.lines[0].set_markersize(12)

b.legend(prop={'size': 25})

# %% [markdown]
# # Epi DisAg Plots - Supplemental

# %%
import re
import gc
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib as mpl
import seaborn as sns

import pandas as pd
import pylab as p
import os
import csv
import numpy as np

from scipy.integrate import odeint

files = [\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Epi Data/Epi CARS to SOME Dis.csv',\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Epi Data/Epi POEM to LAST Dis.csv',\
        ]

EpiDCS = pd.read_csv(files[0],sep =',', lineterminator ='\n')
EpiDPL = pd.read_csv(files[1],sep =',', lineterminator ='\n')

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 5

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Years", y="CARS", data=EpiDCS, alpha=0.5, label='0000')
b = sns.lineplot(x="Years", y="CARE", data=EpiDCS, alpha=0.5, label='0001')
b = sns.lineplot(x="Years", y="CAMS", data=EpiDCS, alpha=0.5, label='0010')
b = sns.lineplot(x="Years", y="CAME", data=EpiDCS, alpha=0.5, label='0011')
b = sns.lineplot(x="Years", y="CORS", data=EpiDCS, alpha=0.5, label='0100')
b = sns.lineplot(x="Years", y="CORE", data=EpiDCS, alpha=0.5, label='0101')
b = sns.lineplot(x="Years", y="COMS", data=EpiDCS, alpha=0.5, label='0110')
b = sns.lineplot(x="Years", y="COME", data=EpiDCS, alpha=0.5, label='0111')
b = sns.lineplot(x="Years", y="SARS", data=EpiDCS, alpha=0.5, label='1000')
b = sns.lineplot(x="Years", y="SARE", data=EpiDCS, alpha=0.5, label='1001')
b = sns.lineplot(x="Years", y="SAMS", data=EpiDCS, alpha=0.5, label='1010')
b = sns.lineplot(x="Years", y="SAME", data=EpiDCS, alpha=0.5, label='1011')
b = sns.lineplot(x="Years", y="SORS", data=EpiDCS, alpha=0.5, label='1100')
b = sns.lineplot(x="Years", y="SORE", data=EpiDCS, alpha=0.5, label='1101')
b = sns.lineplot(x="Years", y="SOMS", data=EpiDCS, alpha=0.5, label='1110')
b = sns.lineplot(x="Years", y="SOME", data=EpiDCS, alpha=0.5, label='1111')

b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"CARS$\rightarrow$SOME epistasis (absolute value)",fontsize=52, pad=10)
b.set_xlabel("Context (years)",fontsize=35)
b.set_ylabel("Epistasis (absolute values)",fontsize=35)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.yaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
for tick in b.get_xticklabels():
    tick.set_rotation(30)
    
markers=(('o'),\
         ('v'),\
         ('^'),\
         ('<'),\
         ('>'),\
         ('s'),\
         ('p'),\
         ('h'),\
         ('X'),\
         ('D'),\
         ('|'),\
         ('x'),\
         ('+'),\
         ('*'),\
         ('d'),\
         (''))

for i in range(0,15):
    b.lines[i].set_markevery(1)
    b.lines[i].set_marker(markers[i])
    b.lines[i].set_markersize(8)
    
b.legend(prop={'size': 20}, bbox_to_anchor=(1.0, 1.0))

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 5

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Years", y="POEM", data=EpiDPL, alpha=0.5, label='0000')
b = sns.lineplot(x="Years", y="POET", data=EpiDPL, alpha=0.5, label='0001')
b = sns.lineplot(x="Years", y="POSM", data=EpiDPL, alpha=0.5, label='0010')
b = sns.lineplot(x="Years", y="POST", data=EpiDPL, alpha=0.5, label='0011')
b = sns.lineplot(x="Years", y="PAEM", data=EpiDPL, alpha=0.5, label='0100')
b = sns.lineplot(x="Years", y="PAET", data=EpiDPL, alpha=0.5, label='0101')
b = sns.lineplot(x="Years", y="PASM", data=EpiDPL, alpha=0.5, label='0110')
b = sns.lineplot(x="Years", y="PAST", data=EpiDPL, alpha=0.5, label='0111')
b = sns.lineplot(x="Years", y="LOEM", data=EpiDPL, alpha=0.5, label='1000')
b = sns.lineplot(x="Years", y="LOET", data=EpiDPL, alpha=0.5, label='1001')
b = sns.lineplot(x="Years", y="LOSM", data=EpiDPL, alpha=0.5, label='1010')
b = sns.lineplot(x="Years", y="LOST", data=EpiDPL, alpha=0.5, label='1011')
b = sns.lineplot(x="Years", y="LAEM", data=EpiDPL, alpha=0.5, label='1100')
b = sns.lineplot(x="Years", y="LAET", data=EpiDPL, alpha=0.5, label='1101')
b = sns.lineplot(x="Years", y="LASM", data=EpiDPL, alpha=0.5, label='1110')
b = sns.lineplot(x="Years", y="LAST", data=EpiDPL, alpha=0.5, label='1111')


b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"POEM$\rightarrow$LAST epistasis (absolute value)",fontsize=52, pad=10)
b.set_xlabel("Context (years)",fontsize=35)
b.set_ylabel("Epistasis (absolute values)",fontsize=35)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.yaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
for tick in b.get_xticklabels():
    tick.set_rotation(30)
    
markers=(('o'),\
         ('v'),\
         ('^'),\
         ('<'),\
         ('>'),\
         ('s'),\
         ('p'),\
         ('h'),\
         ('X'),\
         ('D'),\
         ('|'),\
         ('x'),\
         ('+'),\
         ('*'),\
         ('d'),\
         (''))

for i in range(0,15):
    b.lines[i].set_markevery(1)
    b.lines[i].set_marker(markers[i])
    b.lines[i].set_markersize(8)
    
b.legend(prop={'size': 20}, bbox_to_anchor=(1.0, 0.99))

# %% [markdown]
# # Cw GB Figures - Supplemental

# %%
import re
import gc
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

import pandas as pd
import pylab as p
import os
import csv
import numpy as np

from scipy.integrate import odeint

files = [\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Cw Data/Cw CARS CARE CAME COME SOME GB.csv',\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Cw Data/Cw CARS CARE CAME SAME SOME GB.csv',\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Cw Data/Cw POEM POET POST LOST LAST Gb.csv',\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Cw Data/Cw POEM POET POST PAST LAST GB.csv',\
        ]

path1 = pd.read_csv(files[0],sep =',', lineterminator ='\n',header =None)
path2 = pd.read_csv(files[1],sep =',', lineterminator ='\n',header =None)
path6 = pd.read_csv(files[2],sep =',', lineterminator ='\n',header =None)
path7 = pd.read_csv(files[3],sep =',', lineterminator ='\n',header =None)

path1 = path1.transpose()
path1.columns = ['Year', 'Up/Down', 'Cw Value']
path1['Year'] = path1['Year'].astype(int)
columnsTitles=["Year","Cw Value","Up/Down"]
path1=path1.reindex(columns=columnsTitles)

for i in range(len(path1)):
    if path1.loc[i,'Up/Down'] == 1:
        path1.loc[i,'Up/Down'] = path1.loc[i,'Cw Value']
    else:
        path1.loc[i,'Up/Down'] = path1.loc[i,'Up/Down']
        
for i in range(len(path1)):
    if path1.loc[i,'Up/Down'] == 0:
        path1.loc[i,'Up/Down'] = None
    else:
        path1.loc[i,'Up/Down'] = path1.loc[i,'Up/Down']

#-------------------------------------------------------------------------------
        
path2 = path2.transpose()
path2.columns = ['Year', 'Up/Down', 'Cw Value']
path2['Year'] = path2['Year'].astype(int)
columnsTitles=["Year","Cw Value","Up/Down"]
path2=path2.reindex(columns=columnsTitles)

for i in range(len(path2)):
    if path2.loc[i,'Up/Down'] == 1:
        path2.loc[i,'Up/Down'] = path2.loc[i,'Cw Value']
    else:
        path2.loc[i,'Up/Down'] = path2.loc[i,'Up/Down']
        
for i in range(len(path2)):
    if path2.loc[i,'Up/Down'] == 0:
        path2.loc[i,'Up/Down'] = None
    else:
        path2.loc[i,'Up/Down'] = path2.loc[i,'Up/Down']
        
#-------------------------------------------------------------------------------
        
path6 = path6.transpose()
path6.columns = ['Year', 'Up/Down', 'Cw Value']
path6['Year'] = path6['Year'].astype(int)
columnsTitles=["Year","Cw Value","Up/Down"]
path6=path6.reindex(columns=columnsTitles)

for i in range(len(path6)):
    if path6.loc[i,'Up/Down'] == 1:
        path6.loc[i,'Up/Down'] = path6.loc[i,'Cw Value']
    else:
        path6.loc[i,'Up/Down'] = path6.loc[i,'Up/Down']
        
for i in range(len(path6)):
    if path6.loc[i,'Up/Down'] == 0:
        path6.loc[i,'Up/Down'] = None
    else:
        path6.loc[i,'Up/Down'] = path6.loc[i,'Up/Down']
        
#-------------------------------------------------------------------------------
        
path7 = path7.transpose()
path7.columns = ['Year', 'Up/Down', 'Cw Value']
path7['Year'] = path7['Year'].astype(int)
columnsTitles=["Year","Cw Value","Up/Down"]
path7=path7.reindex(columns=columnsTitles)

for i in range(len(path7)):
    if path7.loc[i,'Up/Down'] == 1:
        path7.loc[i,'Up/Down'] = path7.loc[i,'Cw Value']
    else:
        path7.loc[i,'Up/Down'] = path7.loc[i,'Up/Down']
        
for i in range(len(path7)):
    if path7.loc[i,'Up/Down'] == 0:
        path7.loc[i,'Up/Down'] = None
    else:
        path7.loc[i,'Up/Down'] = path7.loc[i,'Up/Down']

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 10

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Year", y="Cw Value", data=path1, alpha=0.4)
sns.scatterplot(x="Year", y="Up/Down", data=path1, color='r', s=140)

b.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"CARS$\rightarrow$SOME (British-English) within-path competition ($C_W$)",fontsize=33, pad=10)
b.set_xlabel("Context (years)",fontsize=35)
b.set_ylabel("Within-path competition ($C_W$)",fontsize=30)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
b.text(0.47,0.64,r'CARS$\rightarrow$CARE$\rightarrow$CAME$\rightarrow$COME$\rightarrow$SOME',\
       transform=b.transAxes, fontsize=25)
for tick in b.get_xticklabels():
    tick.set_rotation(30)

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 10

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Year", y="Cw Value", data=path2, alpha=0.4)
sns.scatterplot(x="Year", y="Up/Down", data=path2, color='r', s=140)

b.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"CARS$\rightarrow$SOME (British-English) within-path competition ($C_W$)",fontsize=33, pad=10)
b.set_xlabel("Context (years)",fontsize=35)
b.set_ylabel("Within-path competition ($C_W$)",fontsize=30)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
b.text(0.48,0.73,r'CARS$\rightarrow$CARE$\rightarrow$CAME$\rightarrow$SAME$\rightarrow$SOME',\
       transform=b.transAxes, fontsize=25)
for tick in b.get_xticklabels():
    tick.set_rotation(30)

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 10

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Year", y="Cw Value", data=path6, alpha=0.4)
sns.scatterplot(x="Year", y="Up/Down", data=path6, color='r', s=140)

b.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"POEM$\rightarrow$LAST (British-English) within-path competition ($C_W$)",fontsize=33, pad=10)
b.set_xlabel("Context (years)",fontsize=35)
b.set_ylabel("Within-path competition ($C_W$)",fontsize=30)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
b.text(0.49,0.71,r'POEM$\rightarrow$POET$\rightarrow$POST$\rightarrow$LOST$\rightarrow$LAST',\
       transform=b.transAxes, fontsize=25)
for tick in b.get_xticklabels():
    tick.set_rotation(30)

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 10

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Year", y="Cw Value", data=path7, alpha=0.4)
sns.scatterplot(x="Year", y="Up/Down", data=path7, color='r', s=140)

b.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"POEM$\rightarrow$LAST (British-English) within-path competition ($C_W$)",fontsize=34, pad=10)
b.set_xlabel("Context (years)",fontsize=35)
b.set_ylabel("Within-path competition ($C_W$)",fontsize=30)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
b.text(0.49,0.72,r'POEM$\rightarrow$POET$\rightarrow$POST$\rightarrow$LOST$\rightarrow$LAST',\
       transform=b.transAxes, fontsize=25)
for tick in b.get_xticklabels():
    tick.set_rotation(30)

# %% [markdown]
# # EpiAg GB Figures - Supplemental

# %%
import re
import gc
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib as mpl
import seaborn as sns

import pandas as pd
import pylab as p
import os
import csv
import numpy as np

from scipy.integrate import odeint

files = [\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Epi Data/Epi CARS to SOME GB Ag.csv',\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Epi Data/Epi POEM to LAST GB Ag.csv',\
        ]

EpiCSGB = pd.read_csv(files[0],sep =',', lineterminator ='\n')
EpiPLGB = pd.read_csv(files[1],sep =',', lineterminator ='\n')

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 10

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Years", y="0th Order", data=EpiCSGB, alpha=0.5, label='0th Order')
b = sns.lineplot(x="Years", y="1st Order", data=EpiCSGB, alpha=0.5, label='1st Order')
b = sns.lineplot(x="Years", y="2nd Order", data=EpiCSGB, alpha=0.5, label='2nd Order')
b = sns.lineplot(x="Years", y="3rd Order", data=EpiCSGB, alpha=0.5, label='3rd Order')
b = sns.lineplot(x="Years", y="4th Order", data=EpiCSGB, alpha=0.5, label='4th Order')

b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"CARS$\rightarrow$SOME (British-English) epistasis (absolute mean)",fontsize=37, pad=10)
b.set_xlabel("Context (years)",fontsize=35)
b.set_ylabel("Epistasis (mean absolute value)",fontsize=30)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.yaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
# b.legend(loc='best', prop={'size': 25})
for tick in b.get_xticklabels():
    tick.set_rotation(30)
    
b.lines[0].set_markevery(1)
b.lines[0].set_marker(('s'))
b.lines[0].set_markersize(12)

b.lines[1].set_markevery(1)
b.lines[1].set_marker(('o'))
b.lines[1].set_markersize(12)

b.lines[2].set_markevery(1)
b.lines[2].set_marker(('D'))
b.lines[2].set_markersize(12)

b.lines[3].set_markevery(1)
b.lines[3].set_marker(('^'))
b.lines[3].set_markersize(12)

b.lines[4].set_markevery(1)
b.lines[4].set_marker(('X'))
b.lines[4].set_markersize(12)

b.legend(prop={'size': 20})

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 10

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Years", y="0th Order", data=EpiPLGB, alpha=0.5, label='0th Order')
b = sns.lineplot(x="Years", y="1st Order", data=EpiPLGB, alpha=0.5, label='1st Order')
b = sns.lineplot(x="Years", y="2nd Order", data=EpiPLGB, alpha=0.5, label='2nd Order')
b = sns.lineplot(x="Years", y="3rd Order", data=EpiPLGB, alpha=0.5, label='3rd Order')
b = sns.lineplot(x="Years", y="4th Order", data=EpiPLGB, alpha=0.5, label='4th Order')

b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"POEM$\rightarrow$LAST (British-English) epistasis (absolute mean)",fontsize=37, pad=10)
b.set_xlabel("Context (years)",fontsize=35)
b.set_ylabel("Epistasis (mean absolute value)",fontsize=30)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.yaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
# b.legend(loc='best', prop={'size': 25})
for tick in b.get_xticklabels():
    tick.set_rotation(30)
    
b.lines[0].set_markevery(1)
b.lines[0].set_marker(('s'))
b.lines[0].set_markersize(12)

b.lines[1].set_markevery(1)
b.lines[1].set_marker(('o'))
b.lines[1].set_markersize(12)

b.lines[2].set_markevery(1)
b.lines[2].set_marker(('D'))
b.lines[2].set_markersize(12)

b.lines[3].set_markevery(1)
b.lines[3].set_marker(('^'))
b.lines[3].set_markersize(12)

b.lines[4].set_markevery(1)
b.lines[4].set_marker(('X'))
b.lines[4].set_markersize(12)

b.legend(prop={'size': 20}, loc=(0.82,0.43))

# %% [markdown]
# # Epi DisAg GB Figures - Supplemental

# %%
import re
import gc
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib as mpl
import seaborn as sns

import pandas as pd
import pylab as p
import os
import csv
import numpy as np

from scipy.integrate import odeint

files = [\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Epi Data/Epi CARS to SOME GB Dis.csv',\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Epi Data/Epi POEM to LAST GB Dis.csv',\
        ]

EpiDCS = pd.read_csv(files[0],sep =',', lineterminator ='\n')
EpiDPL = pd.read_csv(files[1],sep =',', lineterminator ='\n')

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 4

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Years", y="CARS", data=EpiDCS, alpha=0.5, label='0000')
b = sns.lineplot(x="Years", y="CARE", data=EpiDCS, alpha=0.5, label='0001')
b = sns.lineplot(x="Years", y="CAMS", data=EpiDCS, alpha=0.5, label='0010')
b = sns.lineplot(x="Years", y="CAME", data=EpiDCS, alpha=0.5, label='0011')
b = sns.lineplot(x="Years", y="CORS", data=EpiDCS, alpha=0.5, label='0100')
b = sns.lineplot(x="Years", y="CORE", data=EpiDCS, alpha=0.5, label='0101')
b = sns.lineplot(x="Years", y="COMS", data=EpiDCS, alpha=0.5, label='0110')
b = sns.lineplot(x="Years", y="COME", data=EpiDCS, alpha=0.5, label='0111')
b = sns.lineplot(x="Years", y="SARS", data=EpiDCS, alpha=0.5, label='1000')
b = sns.lineplot(x="Years", y="SARE", data=EpiDCS, alpha=0.5, label='1001')
b = sns.lineplot(x="Years", y="SAMS", data=EpiDCS, alpha=0.5, label='1010')
b = sns.lineplot(x="Years", y="SAME", data=EpiDCS, alpha=0.5, label='1011')
b = sns.lineplot(x="Years", y="SORS", data=EpiDCS, alpha=0.5, label='1100')
b = sns.lineplot(x="Years", y="SORE", data=EpiDCS, alpha=0.5, label='1101')
b = sns.lineplot(x="Years", y="SOMS", data=EpiDCS, alpha=0.5, label='1110')
b = sns.lineplot(x="Years", y="SOME", data=EpiDCS, alpha=0.5, label='1111')

b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"CARS$\rightarrow$SOME (British-English) epistasis (absolute value)",fontsize=38, pad=10)
b.set_xlabel("Context (years)",fontsize=35)
b.set_ylabel("Epistasis (absolute values)",fontsize=30)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.yaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
for tick in b.get_xticklabels():
    tick.set_rotation(30)
    
markers=(('o'),\
         ('v'),\
         ('^'),\
         ('<'),\
         ('>'),\
         ('s'),\
         ('p'),\
         ('h'),\
         ('X'),\
         ('D'),\
         ('|'),\
         ('x'),\
         ('+'),\
         ('*'),\
         ('d'),\
         (''))

for i in range(0,15):
    b.lines[i].set_markevery(1)
    b.lines[i].set_marker(markers[i])
    b.lines[i].set_markersize(8)
    
b.legend(prop={'size': 20}, bbox_to_anchor=(1.0, 0.99))

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 4

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Years", y="POEM", data=EpiDPL, alpha=0.5, label='0000')
b = sns.lineplot(x="Years", y="POET", data=EpiDPL, alpha=0.5, label='0001')
b = sns.lineplot(x="Years", y="POSM", data=EpiDPL, alpha=0.5, label='0010')
b = sns.lineplot(x="Years", y="POST", data=EpiDPL, alpha=0.5, label='0011')
b = sns.lineplot(x="Years", y="PAEM", data=EpiDPL, alpha=0.5, label='0100')
b = sns.lineplot(x="Years", y="PAET", data=EpiDPL, alpha=0.5, label='0101')
b = sns.lineplot(x="Years", y="PASM", data=EpiDPL, alpha=0.5, label='0110')
b = sns.lineplot(x="Years", y="PAST", data=EpiDPL, alpha=0.5, label='0111')
b = sns.lineplot(x="Years", y="LOEM", data=EpiDPL, alpha=0.5, label='1000')
b = sns.lineplot(x="Years", y="LOET", data=EpiDPL, alpha=0.5, label='1001')
b = sns.lineplot(x="Years", y="LOSM", data=EpiDPL, alpha=0.5, label='1010')
b = sns.lineplot(x="Years", y="LOST", data=EpiDPL, alpha=0.5, label='1011')
b = sns.lineplot(x="Years", y="LAEM", data=EpiDPL, alpha=0.5, label='1100')
b = sns.lineplot(x="Years", y="LAET", data=EpiDPL, alpha=0.5, label='1101')
b = sns.lineplot(x="Years", y="LASM", data=EpiDPL, alpha=0.5, label='1110')
b = sns.lineplot(x="Years", y="LAST", data=EpiDPL, alpha=0.5, label='1111')

b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"CARS$\rightarrow$SOME (British-English) epistasis (absolute value)",fontsize=38, pad=10)
b.set_xlabel("Context (years)",fontsize=35)
b.set_ylabel("Epistasis (absolute values)",fontsize=30)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.yaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
for tick in b.get_xticklabels():
    tick.set_rotation(30)
    
markers=(('o'),\
         ('v'),\
         ('^'),\
         ('<'),\
         ('>'),\
         ('s'),\
         ('p'),\
         ('h'),\
         ('X'),\
         ('D'),\
         ('|'),\
         ('x'),\
         ('+'),\
         ('*'),\
         ('d'),\
         (''))

for i in range(0,15):
    b.lines[i].set_markevery(1)
    b.lines[i].set_marker(markers[i])
    b.lines[i].set_markersize(8)

b.legend(prop={'size': 20}, bbox_to_anchor=(1.0, 0.99))

# %% [markdown]
# # 3 & 5 Letter Cw Figures - Supplemental

# %%
import re
import gc
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

import pandas as pd
import pylab as p
import os
import csv
import numpy as np

from scipy.integrate import odeint

files = [\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Cw Data/Cw TEA SEA SEE SHE.csv',\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Cw Data/Cw DARTS DARES FARES FIRES FIRED FILED.csv'\
        ]

path1 = pd.read_csv(files[0],sep =',', lineterminator ='\n',header =None)
path2 = pd.read_csv(files[1],sep =',', lineterminator ='\n',header =None)

path1 = path1.transpose()
path1.columns = ['Year', 'Up/Down', 'Cw Value']
path1['Year'] = path1['Year'].astype(int)
columnsTitles=["Year","Cw Value","Up/Down"]
path1=path1.reindex(columns=columnsTitles)

for i in range(len(path1)):
    if path1.loc[i,'Up/Down'] == 1:
        path1.loc[i,'Up/Down'] = path1.loc[i,'Cw Value']
    else:
        path1.loc[i,'Up/Down'] = path1.loc[i,'Up/Down']
        
for i in range(len(path1)):
    if path1.loc[i,'Up/Down'] == 0:
        path1.loc[i,'Up/Down'] = None
    else:
        path1.loc[i,'Up/Down'] = path1.loc[i,'Up/Down']

#-------------------------------------------------------------------------------
        
path2 = path2.transpose()
path2.columns = ['Year', 'Up/Down', 'Cw Value']
path2['Year'] = path2['Year'].astype(int)
columnsTitles=["Year","Cw Value","Up/Down"]
path2=path2.reindex(columns=columnsTitles)

for i in range(len(path2)):
    if path2.loc[i,'Up/Down'] == 1:
        path2.loc[i,'Up/Down'] = path2.loc[i,'Cw Value']
    else:
        path2.loc[i,'Up/Down'] = path2.loc[i,'Up/Down']
        
for i in range(len(path2)):
    if path2.loc[i,'Up/Down'] == 0:
        path2.loc[i,'Up/Down'] = None
    else:
        path2.loc[i,'Up/Down'] = path2.loc[i,'Up/Down']

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 10

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Year", y="Cw Value", data=path1, alpha=0.4)
sns.scatterplot(x="Year", y="Up/Down", data=path1, color='r', s=140)

b.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"SHE$\rightarrow$TEA within-path competition ($C_W$)",fontsize =45, pad=10)
b.set_xlabel("Context (years)",fontsize=35)
b.set_ylabel("Within-path competition ($C_W$)",fontsize=30)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
b.text(0.14,0.65,r'TEA$\rightarrow$SEA$\rightarrow$SEE$\rightarrow$SHE',\
       transform=b.transAxes, fontsize=25)
for tick in b.get_xticklabels(): 
    tick.set_rotation(30)

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 10

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Year", y="Cw Value", data=path2, alpha=0.4)
sns.scatterplot(x="Year", y="Up/Down", data=path2, color='r', s=140)

b.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"DARTS$\rightarrow$FILED within-path competition ($C_W$)",fontsize=41, pad=10)
b.set_xlabel("Context (years)",fontsize=35)
b.set_ylabel("Within-path competition ($C_W$)",fontsize=30)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
b.text(0.34,0.17,\
       r'DARTS$\rightarrow$DARES$\rightarrow$FARES$\rightarrow$FIRES$\rightarrow$FIRED$\rightarrow$FILED',\
       transform=b.transAxes, fontsize=25)
for tick in b.get_xticklabels(): 
    tick.set_rotation(30)

# %% [markdown]
# # 3 & 5 Letter Epi Figures - Supplemental

# %%
import re
import gc
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib as mpl
import seaborn as sns

import pandas as pd
import pylab as p
import os
import csv
import numpy as np

from scipy.integrate import odeint

files = [\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Epi Data/Epi BAD to DRY.csv',\
         'F:/Professional Stuff/3) Post-Bacc/2) Brown University/Project 2 - \
Epistasis & Lexical Landscapes/Fancy Plots/Epi Data/Epi SHARP to ATONE.csv',\
        ]

EpiBD = pd.read_csv(files[0],sep =',', lineterminator ='\n')
EpiSA = pd.read_csv(files[1],sep =',', lineterminator ='\n')

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 8

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Years", y="BAD", data=EpiBD, alpha=0.5, label='000')
b = sns.lineplot(x="Years", y="BAY", data=EpiBD, alpha=0.5, label='001')
b = sns.lineplot(x="Years", y="BRD", data=EpiBD, alpha=0.5, label='010')
b = sns.lineplot(x="Years", y="DAD", data=EpiBD, alpha=0.5, label='011')
b = sns.lineplot(x="Years", y="DAY", data=EpiBD, alpha=0.5, label='101')
b = sns.lineplot(x="Years", y="DRD", data=EpiBD, alpha=0.5, label='110')
b = sns.lineplot(x="Years", y="DRY", data=EpiBD, alpha=0.5, label='111')

b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"BAD$\rightarrow$DRY epistasis (absolute value)",fontsize=50, pad=10)
b.set_xlabel("Context (years)",fontsize=35)
b.set_ylabel("Epistasis (absolute values)",fontsize=30)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.yaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
for tick in b.get_xticklabels():
    tick.set_rotation(30)
    
b.lines[0].set_markevery(1)
b.lines[0].set_marker(('s'))
b.lines[0].set_markersize(12)

b.lines[1].set_markevery(1)
b.lines[1].set_marker(('o'))
b.lines[1].set_markersize(12)

b.lines[2].set_markevery(1)
b.lines[2].set_marker(('D'))
b.lines[2].set_markersize(12)

b.lines[3].set_markevery(1)
b.lines[3].set_marker(('^'))
b.lines[3].set_markersize(12)

b.lines[4].set_markevery(1)
b.lines[4].set_marker(('X'))
b.lines[4].set_markersize(12)

b.lines[6].set_markevery(1)
b.lines[6].set_marker(('P'))
b.lines[6].set_markersize(13)

b.lines[5].set_markevery(1)
b.lines[5].set_marker(('*'))
b.lines[5].set_markersize(18)

b.legend(prop={'size': 20}, bbox_to_anchor=(1.0, 0.99))

# %%
plt.figure(figsize=(17,9))
mpl.rcParams['lines.linewidth'] = 4

sns.set_style('darkgrid')
sns.set_style({'font.family':'STIXGeneral', 'font.serif':'stix'})

b = sns.lineplot(x="Years", y="SHARP", data=EpiSA, alpha=0.5, label='00000')
b = sns.lineplot(x="Years", y="SHARE", data=EpiSA, alpha=0.5, label='00001')
b = sns.lineplot(x="Years", y="SHANP", data=EpiSA, alpha=0.5, label='00010')
b = sns.lineplot(x="Years", y="SHANE", data=EpiSA, alpha=0.5, label='00011')
b = sns.lineplot(x="Years", y="SHORP", data=EpiSA, alpha=0.5, label='00100')
b = sns.lineplot(x="Years", y="SHORE", data=EpiSA, alpha=0.5, label='00101')
b = sns.lineplot(x="Years", y="SHONP", data=EpiSA, alpha=0.5, label='00110')
b = sns.lineplot(x="Years", y="SHONE", data=EpiSA, alpha=0.5, label='00111')
b = sns.lineplot(x="Years", y="STARP", data=EpiSA, alpha=0.5, label='01000')
b = sns.lineplot(x="Years", y="STARE", data=EpiSA, alpha=0.5, label='01001')
b = sns.lineplot(x="Years", y="STANP", data=EpiSA, alpha=0.5, label='01010')
b = sns.lineplot(x="Years", y="STANE", data=EpiSA, alpha=0.5, label='01011')
b = sns.lineplot(x="Years", y="STORP", data=EpiSA, alpha=0.5, label='01100')
b = sns.lineplot(x="Years", y="STORE", data=EpiSA, alpha=0.5, label='01101')
b = sns.lineplot(x="Years", y="STONP", data=EpiSA, alpha=0.5, label='01110')
b = sns.lineplot(x="Years", y="STONE", data=EpiSA, alpha=0.5, label='01111')
b = sns.lineplot(x="Years", y="AHARP", data=EpiSA, alpha=0.5, label='10000')
b = sns.lineplot(x="Years", y="AHARE", data=EpiSA, alpha=0.5, label='10001')
b = sns.lineplot(x="Years", y="AHANP", data=EpiSA, alpha=0.5, label='10010')
b = sns.lineplot(x="Years", y="AHANE", data=EpiSA, alpha=0.5, label='10011')
b = sns.lineplot(x="Years", y="AHORP", data=EpiSA, alpha=0.5, label='10100')
b = sns.lineplot(x="Years", y="AHORE", data=EpiSA, alpha=0.5, label='10101')
b = sns.lineplot(x="Years", y="AHONP", data=EpiSA, alpha=0.5, label='10110')
b = sns.lineplot(x="Years", y="AHONE", data=EpiSA, alpha=0.5, label='10111')
b = sns.lineplot(x="Years", y="ATARP", data=EpiSA, alpha=0.5, label='11000')
b = sns.lineplot(x="Years", y="ATARE", data=EpiSA, alpha=0.5, label='11001')
b = sns.lineplot(x="Years", y="ATANP", data=EpiSA, alpha=0.5, label='11010')
b = sns.lineplot(x="Years", y="ATANE", data=EpiSA, alpha=0.5, label='11011')
b = sns.lineplot(x="Years", y="ATORP", data=EpiSA, alpha=0.5, label='11100')
b = sns.lineplot(x="Years", y="ATORE", data=EpiSA, alpha=0.5, label='11101')
b = sns.lineplot(x="Years", y="ATONP", data=EpiSA, alpha=0.5, label='11110')
b = sns.lineplot(x="Years", y="ATONE", data=EpiSA, alpha=0.5, label='11111')

b.yaxis.get_offset_text().set_fontsize(20)
b.axes.set_title(r"SHARP$\rightarrow$ATONE epistasis (absolute value)",fontsize=48, pad=10)
b.set_xlabel("Context (years)",fontsize=35)
b.set_ylabel("Epistasis (absolute values)",fontsize=30)
b.tick_params(labelsize=20)
b.xaxis.labelpad = 10
b.yaxis.labelpad = 10
b.xaxis.set_major_locator(plt.MaxNLocator(20))
for tick in b.get_xticklabels():
    tick.set_rotation(30)

markers=(('.'),\
         (','),\
         ('o'),\
         ('v'),\
         ('^'),\
         ('<'),\
         ('>'),\
         ('1'),\
         ('2'),\
         ('3'),\
         ('4'),\
         ('8'),\
         ('s'),\
         ('p'),\
         ('P'),\
         ('*'),\
         ('h'),\
         ('H'),\
         ('+'),\
         ('x'),\
         ('X'),\
         ('D'),\
         ('d'),\
         ('|'),\
         ('_'),\
         ('o'),\
         ('X'),\
         ('h'),\
         ('H'),\
         ('s'),\
         ('o'),\
         ("v"))

for i in range(0,31):
    b.lines[i].set_markevery(1)
    b.lines[i].set_marker(markers[i])
    b.lines[i].set_markersize(7)

b.legend(prop={'size': 13}, bbox_to_anchor=(1.12, 1.09))
